# %% [markdown]
# # Clean pipeline

# %%
import main
from importlib import reload
import display as d
import matplotlib.pyplot as plt
import numpy as np

# %%
reload(main)
reload(d)
# Out:
# <module 'display' from '/Users/thomasvuillaume/Desktop/test_images/display.py'>

# %%
# %pdb

# %%
filename = 'WistarDIV4_3_4.tif'
pipeline = main.main(filename)
# Out:
# The file WistarDIV4_3_4.tif contains 70 images of 1024x1024 pixels
# Video filtered
# Video calibrated
# Video differentiated
# Video denoised
# Video thresholded
# Video eroded
# Video eroded
# Video dilated

# %%
pipeline.find_blob(min_sigma=12, max_sigma=30, overlap=0.2)

# %%
# %matplotlib notebook
d.display_video(pipeline.current_video, cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
d.display_video_blobs(pipeline.original_video , pipeline.blobs)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
reload(d)
# Out:
# <module 'display' from '/Users/thomasvuillaume/Desktop/test_images/display.py'>

# %%
# %matplotlib inline
d.plot_number_blob(pipeline.blobs);

# %%
# %matplotlib inline
d.plot_hist_size_blobs(pipeline.blobs, align='left')

# %%
from skimage.feature import blob_doh

# %%
blob_doh?
